# %%
import numpy as npimport matplotlib.pyplot as plt

# %%
data1 = np.load('data/effz_polish_1_two5x10apd.npz')data2 = np.load('data/effz_polish_1_two5x5apd.npz')d1= data1['data']d2= data2['data']print 'data1:', data1['meta']print 'data2:', data2['meta']
# Out:
# data1: {&apos;draw&apos;: False, &apos;apdy&apos;: 1.0, &apos;apdx&apos;: 0.5, &apos;mfp&apos;: 1000, &apos;length&apos;: 11, &apos;seed&apos;: 31416, &apos;refidx&apos;: &apos;0.0:0.99:10&apos;, &apos;save&apos;: &apos;data/effz_polish_1_two5x10apd&apos;, &apos;n_photons&apos;: &apos;10000&apos;}data2: {&apos;draw&apos;: False, &apos;apdy&apos;: &apos;0.5&apos;, &apos;apdx&apos;: 0.5, &apos;mfp&apos;: 1000, &apos;length&apos;: 11, &apos;seed&apos;: 31416, &apos;refidx&apos;: &apos;0.0:0.99:10&apos;, &apos;save&apos;: &apos;data/effz_polish_1_two5x5apd&apos;, &apos;n_photons&apos;: &apos;10000&apos;}

# %%
fig1= plt.figure(figsize=(8,6))plt.errorbar(d1[:,0], d1[:,1], yerr= d1[:,2], fmt='o', label='two 5x10 APD')plt.errorbar(d2[:,0], d2[:,1], yerr= d2[:,2], fmt='o', label='two 5x5 APD')plt.legend(loc='upper right')plt.xlim(0,11)plt.ylim(ymin=0)plt.ylabel('Efficiency', fontsize='xx-large')plt.xlabel('Distance from sensors (cm)', fontsize='xx-large')plt.grid()
